# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(245, 245, 245, 0.95); color: #2c2c2c; padding: 18px 24px; margin: 16px 0; border-left: 5px solid #666; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.1); backdrop-filter: blur(1.5px);">
#
#
# **Михаил, привет! Рад с тобой познакомиться 😊**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍  Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝  Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. **Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (Сode/Markdown)**.</u>
#
#
# * **Прошу не перемещать и не удалять мои комментарии. Если они будут удалены, то я верну последнюю версию проекта, где они сохранились.**
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента</b><br><br>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Модель для бесконтактного предсказания массы зеленной морской черепахи (Chelonia mydas)

# %% [markdown]
# Автор: Якунин Михаил
#
# Дата: 21 апреля 2026 г.

# %% [markdown]
# ***По этой ссылке можно посмотреть исходный код проекта и скачать последнюю версию: https://github.com/MEYakunin/Sprint10_Tortilla_Center.git***

# %% [markdown]
# ## Цель проекта

# %% [markdown]
# Разработать линейную регрессионную модель для предсказания массы зелёных морских черепах (Chelonia mydas) по бесконтактным биометрическим измерениям (длина/ширина панциря, головы, ласт, количество колец роста и др.). Модель станет частью системы компьютерного зрения TurtleCV, позволяя заменить травматичное взвешивание на расчёт массы по внешним признакам.

# %% [markdown]
# ## *Содержание*

# %% [markdown]
# 1. [Постановка задачи машинного обучения](#1)
# 2. [Подключение и настройка библиотек](#2)
# 3. [Загрузка датасета](#3)
# 4. [Исследовательский анализ данных](#4)
# 5. [Предобработка данных](#5)
# 6. [Обучение моделей](#6)
# 7. [Проверка лучшей модели на тестовой выборке](#7)
# 8. [Оценка важности признаков](#8)
# 9. [Функция для прогнозирования веса черепахи](#9)
# 10. [Общие выводы и рекомендации по дальнейшей работе](#10)

# %% [markdown]
# ## 1. Постановка задачи машинного обучения <a id=1></a>

# %% [markdown]
# <u>**Обоснование выбора модели:**</u>
#
# Целевая переменная — масса черепахи (weight) — является непрерывной числовой величиной (измеряется в килограммах). Необходимо предсказать её точное значение на основе множества биометрических признаков, а не отнести черепаху к какому-либо классу (например, «лёгкая / средняя / тяжёлая»). Линейная регрессия выбрана в силу требования интерпретируемости коэффициентов для последующей реализации в виде простой формулы внутри прибора TurtleCV.
#
# <u>**Почему целевая переменная `weight`:**</u>
# * Именно массу необходимо определять бесконтактно, чтобы снизить стресс у животных.
# * Все остальные поля (`shell_length`, `head_width`, `flipper_length_1` и т.д.) — это признаки, доступные через систему компьютерного зрения без физического контакта.
# * Масса — ключевой параметр для дозирования лекарств, оценки реабилитации и решения о выпуске в океан.
#
# <u>**Критерии качества модели:**</u>
# | Критерий | Пороговое значение | Целевая аудитория / условие |
# |----------|--------------------|------------------------------|
# | MAE | ≤ 5 кг | Для черепах массой от 50 до 150 кг (взрослые особи). В случае наличия в данных более лёгких животных — ошибка может быть меньше, но 5 кг — жёсткая верхняя граница. |
# | MAPE | Чем ниже, тем лучше. | Для всей выборки (разные возрастные группы). Позволяет убедиться, что модель не ошибается систематически на молодых черепахах. |
# | R² | ≥ 0.97 | На валидационной и тестовой выборках. Гарантирует, что модель объясняет почти всю вариативность массы. |
# | Линейность модели | Коэффициенты должны быть интерпретируемы, без нелинейных преобразований (кроме возможного масштабирования признаков) | Требование заказчика для простой реализации в приборе. |
# | Воспроизводимость | Фиксированный random_state во всех случайных процессах (разбиение выборки, регуляризация и т.д.) | Обеспечивает повторяемость результатов. |
#
# В рамках данного проекта решается задача регрессии с целевой переменной weight (масса черепахи, кг). Качество модели оценивается по трём метрикам: MAE ≤ 5 кг (для взрослых особей), MAPE (относительная ошибка) и R² ≥ 0.97 (доля объяснённой дисперсии). Успешной считается линейная модель, которая на тестовой выборке достигает всех трёх пороговых значений, сохраняя интерпретируемость коэффициентов и воспроизводимость результатов.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Да, есть плагин ToC. Но хорошо бы уметь реализовывать интерактивный план проекта вручную.
#
# Как это реализовать - смотри по [ссылке](https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Добавил содержание. Во все прошлые проекты я добавлял содержание, а в этот раз забыл😊
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# ## 2. Подключение и настройка библиотек <a id=2></a>

# %%
# Загружаем библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, SGDRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# ## 3. Загрузка датасета <a id=3></a>

# %%
# Загружаем датасет
df = pd.read_csv('turtles.csv', sep='\t', decimal=',')

# %%
# Выводим общую информацию о датафрейме
display(df.head(5))
df.info()
df.describe(include='all').T
# Out:
#       id          binomial_name               registration number  \
# 0  20438        Caretta caretta  d89af72662f49ece4d09dec75a8b0166
# 1  19034  Lepidochelys olivacea  1579c64777de4db1c16e8b7b0d19c45e
# 2  24689  LEPIDOCHELYS OLIVACEA  bfcec01187569615087e4d777c44985a
# 3  17945  Lepidochelys Olivacea  2c159675aa28f0ea566fce2090bf4c82
# 4  24543  lepidochelys olivacea  ecd22499761e2ac56a6d8eb765ec566d
#
#    shell_length  shell_width  head_length  head_width  flipper_length_1  \
# 0         700.0          381        112.0        82.0               356
# 1         341.0          295         65.0        48.0               216
# 2         408.0          343         71.0        70.0               308
# 3         512.0          432         98.0        95.0               334
# 4         408.0          307         50.0        54.0               280
#
#    flipper_width_1  flipper_length_2  flipper_width_2  flipper_length_3  \
# ...

# %% [markdown]
# **Вывод по исходному датасету:**
# - Датасет содержит 8861 запись и 20 столбцов.
# - Целевая переменная `weight` (масса) имеет пропуски (8842 ненулевых значения) и варьируется от 0 до 617.8 кг. Нулевые значения массы являются артефактом и будут удалены при предобработке.
# - Признаки `shell_length`, `head_length`, `flipper_length_3`, `flipper_width_3` и другие имеют пропуски, что потребует их обработки.
# - Столбец `binomial_name` содержит несколько видов черепах, причём названия видов записаны в разных регистрах (например, `Chelonia mydas`, `chelonia mydas`). Это требует нормализации для фильтрации целевого вида.
# - В данных присутствуют явные выбросы (например, `shell_length` достигает 20240 мм, что в 20 раз превышает типичные значения). Это указывает на ошибки в единицах измерения (вероятно, данные были умножены на 10).
# - Столбцы `id`, `registration number`, `timestamp`, `measure_count` не несут прямой биологической информации о черепахе и могут быть исключены из признакового пространства.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ## 4. Исследовательский анализ данных <a id=4></a>

# %% [markdown]
# ### 4.1 *Отбор целевого вида черепах*

# %%
# Выводим информацию какие виды черепах представлены и в каком количестве
df['binomial_name'].value_counts()
# Out:
# Lepidochelys olivacea     3372
# Chelonia mydas            2325
# Caretta caretta            674
# lepidochelys olivacea      416
# Dermochelys coriacea       399
# Eretmochelys imbricata     332
# Lepidochelys Olivacea      285
# chelonia mydas             252
# Chelonia Mydas             177
# LEPIDOCHELYS OLIVACEA      142
# caretta caretta             90
# CHELONIA MYDAS              75
# Caretta Caretta             46
# eretmochelys imbricata      41
# dermochelys coriacea        40
# CARETTA CARETTA             37
# Eretmochelys Imbricata      28
# Dermochelys Coriacea        27
# Lepidochelys kempii         22
# DERMOCHELYS CORIACEA        18
# ERETMOCHELYS IMBRICATA       8
# lepidochelys kempii          3
# Lepidochelys Kempii          3
# Name: binomial_name, dtype: int64

# %% [markdown]
# В столбце binomial_name представлены различные виды черепах. Так же имеет место написание одного и того же вида по разному. Так как требуется нам строить модель только для морских черепах вида "Chelonia mydas", то следует сначально нармолизовать все назнания и отфильтровать датфрейм по нужному виду черепах.

# %%
# Производим нормализацию данных в столбце "binomial_name"
df['binomial_name'] = df['binomial_name'].str.strip().str.lower()

# %%
# Выводим обновленную информацию о видах и количестве черепах
df['binomial_name'].value_counts()
# Out:
# lepidochelys olivacea     4215
# chelonia mydas            2829
# caretta caretta            847
# dermochelys coriacea       484
# eretmochelys imbricata     409
# lepidochelys kempii         28
# Name: binomial_name, dtype: int64

# %%
# Отфильтруем датафрейм по черепахи вида "chelonia mydas"
c_mydas_df = df[df['binomial_name'] == 'chelonia mydas']

# %%
# Вывидем общую информацию о новом датафрейме
c_mydas_df.describe(include='all').T
# Out:
#                       count unique                               top  freq  \
# id                   2829.0    NaN                               NaN   NaN
# binomial_name          2829      1                    chelonia mydas  2829
# registration number    2825   2484  ffea4045eb77613697d0cb118f2d3495     2
# shell_length         2794.0    NaN                               NaN   NaN
# shell_width          2829.0    NaN                               NaN   NaN
# head_length          2790.0    NaN                               NaN   NaN
# head_width           2790.0    NaN                               NaN   NaN
# flipper_length_1     2829.0    NaN                               NaN   NaN
# flipper_width_1      2829.0    NaN                               NaN   NaN
# flipper_length_2     2829.0    NaN                               NaN   NaN
# flipper_width_2      2829.0    NaN                               NaN   NaN
# ...

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Названия видов приведены к нижнему регистру и очищены от пробелов через str.strip().str.lower(). Фильтрация по нужному виду выполнена корректно.
# </div>

# %% [markdown]
# ### 4.2 *Обработка пропусков, дубликатов и выбросов*

# %% [markdown]
# Проверим данные на явные дубликаты. Так как количество строк в датафрейме 2829, а при этом количество уникальных регистрационных номеров в столбце `registration number` только 2484.

# %%
# Выводим количество строк с дубликатами
c_mydas_df.duplicated().sum()
# Out:
# 341

# %%
# Удаляем строки с явными дубликатами
c_mydas_df = c_mydas_df.drop_duplicates()

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Дубликаты удалены только по столбцу registration number. Это неверный подход. Одна черепаха может измеряться несколько раз - у неё будет один регистрационный номер, но разные биометрические показатели. Такие записи удалять не нужно, это разные измерения. Дубликатами являются строки, где совпадают все значения сразу. Нужно использовать drop_duplicates() без указания subset, либо указать все значимые биометрические столбцы и целевую переменную. Из-за данного подхода часть валидных измерений могла быть потеряна.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Учту на будующее, что может быть подвох в таком подходе. Но в данной ситуации я перед удалеием, анализировал все дубликаты и убедился что дублирующие строки по регистрационному номеру имеют одинаковые биометрические паказатели. Поэтому при удаления указателя столбца из `drop_duplicates()` не изменилось количество строк в датафрейме.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# Для обучения модели, нам требуются признаки с числовыми значениями. Поэтому из датафрейма `c_mydas_df` можно удалить столбцы `id`, `binomial_name`, `registration number`.
# Так же можно удалить столбец `timestamp`, эти данные ни как не характерезуют вид черепахи. это всего лишь дата записи признаков. Столбец `measure_count`, тоже можно удалить, по пречине того, что количество проведенных измерений характерезует кажество измерений но не вид черепах.

# %%
# Производим удаление не информативных признаков из датафрейма
c_mydas_df = c_mydas_df.drop(columns=['id', 'binomial_name', 'registration number', 'measure_count', 'timestamp'])
c_mydas_df.head(5)
# Out:
#     shell_length  shell_width  head_length  head_width  flipper_length_1  \
# 8          742.0          652        118.0       147.0               411
# 11        1336.0         1318        207.0       248.0               845
# 16        1010.0          926        216.0       156.0               562
# 20         703.0          606          NaN         NaN               355
# 21         982.0          940        187.0       157.0               518
#
#     flipper_width_1  flipper_length_2  flipper_width_2  flipper_length_3  \
# 8               386               507              389             414.0
# 11              704               661              768             587.0
# 16              488               529              432             467.0
# 20              382               411              340             302.0
# 21              557               545              463             497.0
#
#     flipper_width_3  flipper_length_4  flipper_width_4  circle_count  \
# ...

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Обоснование удаления каждого признака написано правильно. Особенно верно про measure_count - количество измерений характеризует процесс сбора данных, а не саму черепаху.
# </div>

# %% [markdown]
# Проанализируем датафрейм на пропуски в ячейках.

# %%
# Расчитываем количество пропусков
c_mydas_df.isna().sum()
# Out:
# shell_length          29
# shell_width            0
# head_length           35
# head_width            35
# flipper_length_1       0
# flipper_width_1        0
# flipper_length_2       0
# flipper_width_2        0
# flipper_length_3      29
# flipper_width_3       29
# flipper_length_4      29
# flipper_width_4       29
# circle_count           0
# shell_crack         1889
# weight                 2
# dtype: int64

# %% [markdown]
# Пустые ячейки скорее всего являются ошибкой выгрузки или ошибкой заполнения данных в процессе измерения. В любом случае, заполнять данные средним или иными данными не целесообразно, так как это может внести искожение в данные. По этому стоит строки с пустыми данными удалить. Это касается всех данных, кроме столбца `shell_crack`, здесь скорее пропуски обозначают тот факт что на панцере черепах отсутствуют трещины, поэтому значения не вносились. Поэтой причине, пустые ячейки в столбце `shell_crack` на референсное значение 0.

# %%
# Удаляем пустые строки
cols_to_drop = [col for col in c_mydas_df.columns if col != 'shell_crack']
c_mydas_df = c_mydas_df.dropna(subset=cols_to_drop)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Удаление строк с пропусками сделано до разбивки на выборки. В данном случае это не критично, так как строки удалялись целиком и утечки данных нет. Но правильный порядок должен быть такой: сначала train_test_split, потом обработка пропусков. Если в будущем вместо удаления понадобится заполнение медианой - считать её нужно только по обучающей выборке и применять к val и test. Пропуски в целевой переменной weight удалить сразу - допустимо.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# В данной ситуации я понимал что я делаю. Я изначально принял решение что нулевые строки буду удалять, по этому сделал это до разделение на выборки. Естественно если бы я не удалял строки с пропусками, а обробатывал пустые ячейки, то проделывал бы после разбиения датафрейма. Так как былабы учечьки информации при обучение модели, так же как если бы мы делали маштабирование признаков до разделения на выборки.
# </div>

# %%
# Заменяем пустые ячейки на 0 в столбце "shell_crack"
c_mydas_df['shell_crack'] = c_mydas_df['shell_crack'].fillna(0)

# %%
# Производим замену пустых ячеек
c_mydas_df.isna().sum()
# Out:
# shell_length        0
# shell_width         0
# head_length         0
# head_width          0
# flipper_length_1    0
# flipper_width_1     0
# flipper_length_2    0
# flipper_width_2     0
# flipper_length_3    0
# flipper_width_3     0
# flipper_length_4    0
# flipper_width_4     0
# circle_count        0
# shell_crack         0
# weight              0
# dtype: int64

# %%
# Вывидем общую информацию о датафрейме
c_mydas_df.describe(include='all').T
# Out:
#                    count         mean         std    min        25%       50%  \
# shell_length      2396.0  1048.943239  574.727627  645.0  837.00000  980.5000
# shell_width       2396.0   946.114357  514.994624  564.0  755.00000  890.0000
# head_length       2396.0   169.601419   41.295475   87.0  138.00000  163.0000
# head_width        2396.0   183.053005   45.087946   96.0  148.00000  176.0000
# flipper_length_1  2396.0   612.154424  141.961177  339.0  502.00000  588.0000
# flipper_width_1   2396.0   549.551336  131.515230  245.0  450.00000  528.0000
# flipper_length_2  2396.0   611.876461  138.171854  327.0  505.00000  591.0000
# flipper_width_2   2396.0   550.731636  130.765606  276.0  449.00000  533.5000
# flipper_length_3  2396.0   487.274624  110.172469  282.0  400.00000  473.0000
# flipper_width_3   2396.0   440.653172  105.235199  231.0  357.00000  426.0000
# flipper_length_4  2396.0   489.369783  112.254956  254.0  400.00000  473.0000
# ...

# %% [markdown]
# В столбце с указанием массы черепах `weight`, есть строки с нуливыми значениями. Обучать модель на данных, где целевая переменная равна нулю нельзя, поэтому так же удалим из датафрема таки строки.

# %%
# Удаляем строки с 0 значением массы черепах
c_mydas_df = c_mydas_df[c_mydas_df['weight'] != 0]

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Нулевые значения в целевой переменной найдены и удалены - верное решение. Черепах с нулевым весом не существует, это явная ошибка в данных.
# </div>

# %%
# Построим графики распределения и размаха длины и ширины панцеря
plt.figure(figsize=(15, 5))

plt.subplot(2, 2, 1)
sns.histplot(x=c_mydas_df['shell_length'])
plt.title('Распределение значений длины панцаря')
plt.xlabel('Длина панцеря')
plt.ylabel('Частота')

plt.subplot(2, 2, 2)
sns.histplot(x=c_mydas_df['shell_width'])
plt.title('Распределение значений штрины панцаря')
plt.xlabel('Ширина панцеря')
plt.ylabel('Частота')

plt.subplot(2, 2, 3)
sns.boxplot(x=c_mydas_df['shell_length'])
plt.title('Размах длины панцаря')
plt.ylabel('Кол-во')

plt.subplot(2, 2, 4)
sns.boxplot(x=c_mydas_df['shell_width'])
plt.title('Размах ширины панцаря')
plt.ylabel('Кол-во')

plt.tight_layout()
plt.show()

# %% [markdown]
# Как видем из графиком имеются выброссы. Но нам Заказчик сообщил, что во время измерений были ошибки с размерностью данных. Вместо указания значений в мм, измеренные данные были дополнительно умноженны на 10. Очень похоже что наши выбросы и есть ошибочные данные. Поэтому мы можем их поделить на 10.

# %%
# Произведем уменьшение разрядности данных
mask = c_mydas_df['shell_length'] > 2000
c_mydas_df.loc[mask, 'shell_length'] = c_mydas_df.loc[mask, 'shell_length'] / 10

mask = c_mydas_df['shell_width'] > 2000
c_mydas_df.loc[mask, 'shell_width'] = c_mydas_df.loc[mask, 'shell_width'] / 10

# %%
# Построим графики распределения и размаха длины и ширины панцеря
plt.figure(figsize=(15, 5))

plt.subplot(2, 2, 1)
sns.histplot(x=c_mydas_df['shell_length'])
plt.title('Распределение значений длины панцаря')
plt.xlabel('Длина панцеря')
plt.ylabel('Частота')

plt.subplot(2, 2, 2)
sns.histplot(x=c_mydas_df['shell_width'])
plt.title('Распределение значений штрины панцаря')
plt.xlabel('Ширина панцеря')
plt.ylabel('Частота')

plt.subplot(2, 2, 3)
sns.boxplot(x=c_mydas_df['shell_length'])
plt.title('Размах длины панцаря')
plt.ylabel('Кол-во')

plt.subplot(2, 2, 4)
sns.boxplot(x=c_mydas_df['shell_width'])
plt.title('Размах ширины панцаря')
plt.ylabel('Кол-во')

plt.tight_layout()
plt.show()

# %% [markdown]
# Теперь распределение данных стало нормального вида и графики размаха стали без явных выбросов.
#
# Оченим на сколько осталась репрезетативна выборка после всех предобработак.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Выбросы в shell_length обнаружены визуально и исправлены делением на 10 - верное решение. Хорошо, что ты показал графики до и после исправления - наглядно видно результат.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Исправление выбросов применено только к shell_length, но не к shell_width. Из describe() в начале видно, что максимальное значение shell_width равно 11550 мм - это точно такой же выброс той же природы, что и в shell_length. Нужно добавить аналогичное исправление:
#
# ```pythonmask = c_mydas_df['shell_width'] > 2000
# c_mydas_df.loc[mask, 'shell_width'] = c_mydas_df.loc[mask, 'shell_width'] / 10```
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Исправил, добавил уменьшение размерности значений и по столбцу `shell_width`.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
# Исправлено верно
# </div>

# %%
# Расчитываем объем удаленных данных
print(f'Процент удаленных строк: {round(1 - c_mydas_df.shape[0] / df[df["binomial_name"] == "chelonia mydas"].shape[0], 2) * 100}%')
# Out:
# Процент удаленных строк: 15.0%

# %% [markdown]
# **Вывод по обработке данных:**
#
# В ходе предварительной обработки данных были выполнены следующие шаги и получены следующие результаты:
#
# <u>1. Удаление дубликатов</u>
# - В отфильтрованном датафрейме вида `Chelonia mydas` было обнаружено 2829 строк.
# - Количество уникальных регистрационных номеров (`registration number`) составило 2484, что указывает на наличие 341 дублирующей строки (явные дубликаты по идентификатору черепахи).
# - Строки с дублирующимися `registration number` были удалены. Это обоснованно, так как повторные записи об одной и той же особи не должны влиять на обучение модели и могут привести к перекосу данных.
#
# <u>2. Удаление неинформативных признаков</u>
# - Из датафрейма были исключены столбцы, не несущие биологической информации о черепахе:
#     - `id` — технический идентификатор измерения.
#     - `binomial_name` — после фильтрации остался только один вид.
#     - `registration number` — идентификатор особи, не влияет на массу.
#     - `measure_count` — количество измерений, а не биологический параметр.
#     - `timestamp` — время внесения данных.
#
# - *Результат:* размерность признакового пространства сокращена до 14 биометрических признаков и целевой переменной `weight`.
#
# <u>3. Анализ и обработка пропусков</u>
# - Результаты первичного анализа пропусков:
#     - `shell_crack` — 1887 пропусков (около 67% от 2829 строк). Предположительно, пропуски означают отсутствие трещин.
#     - `shell_length`, `head_length`, `head_width`, `flipper_length_3`, `flipper_width_3`, `flipper_length_4`, `flipper_width_4` — от 29 до 35 пропусков (менее 1.5%).
#     - `weight` — 2 пропуска (менее 0.1%).
#
# - Принятые решения:
#     - Строки с пропусками в биометрических признаках (`shell_length`, `head_length`, размеры ласт) были удалены, так как:
#         - Доля пропусков крайне мала (< 1.5%) и не повлияет на репрезентативность.
#         - Заполнение средними или медианными значениями могло бы внести искажения в распределение.
#     - Пропуски в столбце `shell_crack` были заменены на 0, что интерпретируется как "отсутствие трещин на панцире".
#     - Строки с нулевым значением `weight` (масса = 0 кг) были удалены, так как это физически невозможно для живой особи и является ошибкой измерений.
#
# <u>4. Обнаружение и обработка выбросов</u>
# - При визуальном анализе графиков распределения и "ящиков с усами" были обнаружены экстремальные выбросы:
#     - `shell_length` достигает 20240 мм (среднее ~1050 мм).
#     - `shell_width` достигает 11550 мм (среднее ~950 мм).
# - *Причина:* согласно информации от заказчика, в процессе сбора данных некоторые измерения были ошибочно умножены на 10 (вероятно, перепутаны мм и см, либо добавлен лишний ноль).
# - *Действие:* для всех значений `shell_length` и `shell_width` больше 2000 мм выполнено деление на 10.
# - *Результат после коррекции:*
#     - Графики распределения приобрели нормальный вид.
#     - Графики "ящик с усами" перестали показывать аномальные выбросы.
#     - Данные приведены к единой размерности (мм).
#
# <u>5. Итоговая оценка репрезентативности выборки</u>
# - Первоначальное количество строк для вида *Chelonia mydas*: 2829.
# - После всех этапов очистки (удаление дубликатов, пропусков, нулевой массы) осталось: 2393 строки.
# - *Процент удалённых данных:*
#         (2829 − 2393) / 2829 × 100% ≈ 15.0%
# - *Вывод:* удаление 15% данных является допустимым, так как:
#     - Удалялись не случайные строки, а явные дубликаты, технические ошибки и физически невозможные значения.
#     - Оставшаяся выборка (2393 особи) достаточно репрезентативна для построения линейной регрессионной модели.
#     - Распределения признаков после очистки соответствуют ожидаемым биологическим закономерностям.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Отличный итоговый вывод по разделу! Cтруктурированный, с обоснованием каждого решения. Особенно хорошо расписан раздел про выбросы и про обработку shell_crack.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Скорректировал вывод. У меня почему-то изменился процент удаленных данных: с 16% до 15%. Не очень понял из-за чего так произашло🤔
# </div>

# %% [markdown]
# ### 4.3 *Корреляционный анализ*

# %%
# Вычислим корреляционную матрицу (метод Пирсона) 
corr_matrix = c_mydas_df.corr()
weight_corr = corr_matrix[corr_matrix.index != 'weight']['weight'].sort_values(ascending=False).to_frame()

sns.heatmap(weight_corr,
           annot=True,
           fmt='.2f',
           cmap='coolwarm',
           linewidths=0.5,
           cbar=False)

plt.title('Тепловая карта корреляции массы черепахи (метод Пирсона)')
plt.show()

# %%
# Вычислим корреляционную матрицу (метод Спирмена) 
corr_matrix = c_mydas_df.corr(method='spearman')
weight_corr = corr_matrix[corr_matrix.index != 'weight']['weight'].sort_values(ascending=False).to_frame()

sns.heatmap(weight_corr,
           annot=True,
           fmt='.2f',
           cmap='coolwarm',
           linewidths=0.5,
           cbar=False)

plt.title('Тепловая карта корреляции массы черепахи (метод Спирмена)')
plt.show()

# %%
# Строим мультиколлинеарную тепловую карту
sns.heatmap(corr_matrix[corr_matrix.index != 'weight'].drop(columns=['weight']),
           annot=True,
           fmt='.2f',
           cmap='coolwarm',
           linewidths=0.5,
           cbar=False)

plt.show()

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Корреляция посчитана методом Пирсона - это дефолтный метод в pandas. Для данных с асимметричным распределением, как здесь, более корректным был бы метод Спирмена: df.corr(method='spearman'). Результат будет похожим, но интерпретация точнее.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Добавил еще одну ячейку с расчетом корреляции по методу Спирмена. В общем картина не поменялась. Но локально коэффициент корреляции не немного увеличелся (например shell_length: 0.98 -> 0.99).
# </div>

# %% [markdown]
# **Вывод по корреляционному анализу:**
# - Все биометрические признаки (`shell_length`, `shell_width`, размеры ласт, `head_length`, `head_width`) имеют высокую положительную корреляцию с массой (`weight`), что ожидаемо: чем крупнее черепаха, тем она тяжелее. Наиболее сильная связь у `shell_length` (0.99) и `shell_width` (0.97).
# - `circle_count` и `shell_crack` не имеют значимой корреляции (0.49 и 0.03)
# - *Мультиколлинеарность:* признаки сильно коррелируют между собой (например, `shell_length` и `shell_width` — 0.96; `head_length` и `head_width` - 0,76; размеры разных ласт — 0.8-0.9). Это может быть проблемой для интерпретации коэффициентов линейной регрессии, но не критично для предсказательной способности. Для борьбы с этим можно использовать регуляризацию (Ridge, Lasso).

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# В выводе ты пишешь: "Наиболее сильная связь у head_length (0.95) и head_width (0.94)", а также "circle_count и shell_crack также умеренно коррелирует с массой (0.88 и 0.84)". Эти значения вызывают сомнение - обычно наибольшую корреляцию с весом имеют shell_length и shell_width, а circle_count имеет значительно более низкую корреляцию. Похоже, что при интерпретации тепловой карты признаки были перепутаны. Проверь, пожалуйста, значения на графике и скорректируй вывод.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Тут присутствует какая-то мистика. Я проект делал локально в VS Code, и у меня показывалась другая корреляция (та какая была описана в выводе), почему она поменялась не могу понять.
# ![image-4.png](attachment:image-4.png)
#
# Так же изменилась карта и для мультиколлинеарности:
# ![image-3.png](attachment:image-3.png)
#
# Я то же подумал что это странно, но не стал как-то перепроверять (точнее не понимал как можно перепроверить доставерность полученной информации).
#
# Сейчас же и у меня локально показывается корреляция похожую как в тренажере. Почему-то в тренажере у большенства биометрических паказателей коэффецент больне на 0.01, а показатель `shell_crack` в тренажере 0.03, а у меня 0.16😕
# В любом случае я вывод скорректировал под данные из тренажера.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
# Скорей всего, когда ты работал локально, выбросы в shell_width ещё не были исправлены - из-за этого корреляции считались по искажённым данным и были другими. После исправления выбросов данные изменились, поэтому и корреляции стали другими. Думаю этим мистика и объясняется :)
# </div>

# %% [markdown]
# ## 5. Предобработка данных <a id=5></a>

# %% [markdown]
# ### 5.1 *Разделение данных на обучающую, валидационную и тестовую выборки*

# %%
# Разделяем данные
X_temp, X_test, y_temp, y_test = train_test_split(
    c_mydas_df.drop(columns=['weight']), 
    c_mydas_df['weight'], 
    test_size=0.2,
    shuffle=True,
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp,
    y_temp,
    test_size=0.25,
    shuffle=True,
    random_state=42
)

# Проверьте размерности полученных переменных
print(f''' Размер выборок:
    X_train - {X_train.shape};  y_train - {y_train.shape}
    X_val - {X_val.shape};     y_val - {y_val.shape}
    X_test - {X_test.shape};    y_test - {y_test.shape}'''
)
# Out:
#  Размер выборок:
#     X_train - (1435, 14);  y_train - (1435,)
#     X_val - (479, 14);     y_val - (479,)
#     X_test - (479, 14);    y_test - (479,)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
#  Разбивка сделана в правильной пропорции 60/20/20, зафиксирован random_state=42. Хорошая привычка - сразу выводить размеры выборок для самопроверки.
# </div>

# %% [markdown]
# ## 6. Обучение моделей <a id=6></a>

# %%
# Создание функции рассчета метрик модели
def get_metrics(y_true, y_pred, model_name, dataset_name='default'):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    
    return pd.DataFrame({
        'Model': [model_name],
        'Dataset': [dataset_name],
        'MAE': [round(mae, 2)],
        'MSE': [round(mse, 2)],
        'RMSE': [round(rmse, 2)],
        'R2': [round(r2, 2)],
        'MAPE (%)': [round(mape, 2)]
    })

# %%
# Варианты масштабирования
scalers = {
    'no_scale': None,               
    'standard': StandardScaler(),
    'minmax': MinMaxScaler()
}

# Варианты потерь для SGD
loss_functions = ['squared_loss', 'huber', 'epsilon_insensitive']

# Варианты регуляризации для SGD
penalties = ['l2', 'l1', 'elasticnet']

# Варианты коэффициента регулиризации
coeff_regul = [0.01, 0.1, 1.0, 10.0]

# Список для хранения всех результатов
all_results = pd.DataFrame(columns=['Model', 'Dataset', 'MAE', 'MSE', 'RMSE', 'R2', 'MAPE (%)'])

# Устанавлиаем формат вывода числовых данных в датафреймах
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ### 6.1 *Построение базовой модели(Dummy)*

# %%
# Построение модели Dummy Regressor
model_dummy = DummyRegressor(strategy='mean')
model_dummy.fit(X_train, y_train)

y_pred_dummy = model_dummy.predict(X_val)

# %%
# Сохраняем результаты в DataFrame
result = get_metrics(y_val, y_pred_dummy, 'Dummy (mean)')
all_results = pd.concat([all_results, result], ignore_index=True)
print("Базовый уровень (Dummy):")
display(result)
# Out:
# Базовый уровень (Dummy):
#           Model  Dataset   MAE     MSE  RMSE    R2  MAPE (%)
# 0  Dummy (mean)  default 28.63 1194.87 34.57 -0.01     33.85

# %% [markdown]
# ### 6.2 *Построение линейной модели(LinearRegression)*

# %%
# Список для временного хранения результатов каждой модели
temp_result = pd.DataFrame()

# Построение модели LinearRegression
for scale_name, scaler in scalers.items():
    if scaler:
        lr_pipe = make_pipeline(scaler, LinearRegression())
    else:
        lr_pipe = LinearRegression()
    
    lr_pipe.fit(X_train, y_train)
    y_pred = lr_pipe.predict(X_val)
    result = get_metrics(y_val, y_pred, 'LinearRegression', scale_name)
    temp_result = pd.concat([temp_result, result], ignore_index=True)
    all_results = pd.concat([all_results, result], ignore_index=True)
    

display(temp_result.sort_values(['MAE', 'R2']))
# Out:
#               Model   Dataset  MAE   MSE  RMSE   R2  MAPE (%)
# 0  LinearRegression  no_scale 3.35 19.49  4.41 0.98      3.78
# 1  LinearRegression  standard 3.35 19.49  4.41 0.98      3.78
# 2  LinearRegression    minmax 3.35 19.49  4.41 0.98      3.78

# %% [markdown]
# ### 6.3 *Построение линейной модели(Lasso)*

# %%
# Список для временного хранения результатов каждой модели
temp_result = pd.DataFrame()

# Построение модели Lasso
for scale_name, scaler in scalers.items():
    for alpha in coeff_regul:
        if scaler:
            lasso_pipe = make_pipeline(scaler, Lasso(alpha=alpha, random_state=42))
        else:
            lasso_pipe = Lasso(alpha=alpha, random_state=42)
        
        lasso_pipe.fit(X_train, y_train)
        y_pred =lasso_pipe.predict(X_val)
        result = get_metrics(y_val, y_pred, f'Lasso(alpha={alpha})', scale_name)
        temp_result = pd.concat([temp_result, result], ignore_index=True)
        all_results = pd.concat([all_results, result], ignore_index=True)

display(temp_result.sort_values(['MAE', 'R2']))
# Out:
#                 Model   Dataset   MAE     MSE  RMSE    R2  MAPE (%)
# 6    Lasso(alpha=1.0)  standard  3.27   20.08  4.48  0.98      3.53
# 3   Lasso(alpha=10.0)  no_scale  3.32   19.31  4.39  0.98      3.74
# 5    Lasso(alpha=0.1)  standard  3.32   19.34  4.40  0.98      3.74
# 2    Lasso(alpha=1.0)  no_scale  3.33   19.32  4.40  0.98      3.77
# 8   Lasso(alpha=0.01)    minmax  3.33   19.41  4.41  0.98      3.76
# 1    Lasso(alpha=0.1)  no_scale  3.34   19.40  4.40  0.98      3.78
# 4   Lasso(alpha=0.01)  standard  3.34   19.47  4.41  0.98      3.78
# 9    Lasso(alpha=0.1)    minmax  3.34   19.96  4.47  0.98      3.69
# 0   Lasso(alpha=0.01)  no_scale  3.35   19.48  4.41  0.98      3.78
# 10   Lasso(alpha=1.0)    minmax  4.97   48.25  6.95  0.96      5.18
# 7   Lasso(alpha=10.0)  standard  8.72  124.89 11.18  0.89      9.75
# 11  Lasso(alpha=10.0)    minmax 28.63 1194.87 34.57 -0.01     33.85

# %% [markdown]
# ### 6.4 *Построение линейной модели(Ridge)*

# %%
# Список для временного хранения результатов каждой модели
temp_result = pd.DataFrame()

# Построение модели Ridge
for scale_name, scaler in scalers.items():
    for alpha in coeff_regul:
        if scaler:
            ridge_pipe = make_pipeline(scaler, Ridge(alpha=alpha, random_state=42))
        else:
            ridge_pipe = Ridge(alpha=alpha, random_state=42)
        
        ridge_pipe.fit(X_train, y_train)
        y_pred = ridge_pipe.predict(X_val)
        result = get_metrics(y_val, y_pred, f'Ridge(alpha={alpha})', scale_name)
        temp_result = pd.concat([temp_result, result], ignore_index=True)
        all_results = pd.concat([all_results, result], ignore_index=True)

display(temp_result.sort_values(['MAE', 'R2']))
# Out:
#                 Model   Dataset  MAE   MSE  RMSE   R2  MAPE (%)
# 7   Ridge(alpha=10.0)  standard 3.34 19.42  4.41 0.98      3.76
# 9    Ridge(alpha=0.1)    minmax 3.34 19.45  4.41 0.98      3.78
# 10   Ridge(alpha=1.0)    minmax 3.34 19.52  4.42 0.98      3.76
# 0   Ridge(alpha=0.01)  no_scale 3.35 19.49  4.41 0.98      3.78
# 1    Ridge(alpha=0.1)  no_scale 3.35 19.49  4.41 0.98      3.78
# 2    Ridge(alpha=1.0)  no_scale 3.35 19.49  4.41 0.98      3.78
# 3   Ridge(alpha=10.0)  no_scale 3.35 19.49  4.41 0.98      3.78
# 4   Ridge(alpha=0.01)  standard 3.35 19.49  4.41 0.98      3.78
# 5    Ridge(alpha=0.1)  standard 3.35 19.49  4.41 0.98      3.78
# 6    Ridge(alpha=1.0)  standard 3.35 19.47  4.41 0.98      3.78
# 8   Ridge(alpha=0.01)    minmax 3.35 19.48  4.41 0.98      3.78
# 11  Ridge(alpha=10.0)    minmax 3.51 22.03  4.69 0.98      3.83

# %% [markdown]
# ### 6.5 *Построение линейной модели(SGDRegressor)*

# %%
# Список для временного хранения результатов каждой модели
temp_result = pd.DataFrame()

# Построение модели SGDRegressorge
for scale_name, scaler in scalers.items():
    for loss in loss_functions:
        for penalty in penalties:
            if scaler:
                sgd_pipe = make_pipeline(scaler, SGDRegressor(
                                                    loss=loss,
                                                    penalty=penalty,
                                                    max_iter=4000,
                                                    random_state=42                                        
                                                ))
            else:
                sgd_pipe = SGDRegressor(
                                loss=loss,
                                penalty=penalty,
                                max_iter=4000,
                                random_state=42            
                            )
            sgd_pipe.fit(X_train, y_train)
            y_pred = sgd_pipe.predict(X_val)
            result = get_metrics(y_val, y_pred, f'SGD({loss}, {penalty})', scale_name)
            temp_result = pd.concat([temp_result, result], ignore_index=True)
            all_results = pd.concat([all_results, result], ignore_index=True)
        
display(temp_result.sort_values(['MAE', 'R2']))
# Out:
#                                    Model   Dataset                 MAE  \
# 9                  SGD(squared_loss, l2)  standard                3.33
# 10                 SGD(squared_loss, l1)  standard                3.33
# 11         SGD(squared_loss, elasticnet)  standard                3.33
# 15          SGD(epsilon_insensitive, l2)  standard                3.36
# 16          SGD(epsilon_insensitive, l1)  standard                3.36
# 17  SGD(epsilon_insensitive, elasticnet)  standard                3.36
# 18                 SGD(squared_loss, l2)    minmax                3.57
# 19                 SGD(squared_loss, l1)    minmax                3.57
# 20         SGD(squared_loss, elasticnet)    minmax                3.57
# 26  SGD(epsilon_insensitive, elasticnet)    minmax                3.85
# 24          SGD(epsilon_insensitive, l2)    minmax                3.86
# 25          SGD(epsilon_insensitive, l1)    minmax                3.86
# ...

# %% [markdown]
# ### 6.6 Сравнение моделей на валидационной выборке

# %%
# Сортируем по MAE (чем меньше, тем лучше)
final_results_sorted = all_results.sort_values('MAE').reset_index(drop=True)

print("\n=== ИТОГОВАЯ ТАБЛИЦА РЕЗУЛЬТАТОВ (топ 5 моделей) ===")
pd.set_option('display.float_format', '{:.2f}'.format)
print(final_results_sorted.head(5).to_string())

# Проверка, что базовая модель не лучшая
dummy_mae = final_results_sorted[final_results_sorted['Model'] == 'Dummy (mean)']['MAE'].values[0]
better_than_dummy = final_results_sorted[final_results_sorted['MAE'] < dummy_mae]

print(f"\nБазовый MAE = {dummy_mae:.4f}")
print(f"Моделей лучше базовой: {len(better_than_dummy)}")

# Лучшая модель
best_model = final_results_sorted.iloc[0]
print(f"\nЛучшая модель: {best_model['Model']} на датасете {best_model['Dataset']}")
print(f"MAE = {best_model['MAE']:.4f}, R2 = {best_model['R2']:.4f}")
# Out:
# === ИТОГОВАЯ ТАБЛИЦА РЕЗУЛЬТАТОВ (топ 5 моделей) ===
#                    Model   Dataset  MAE   MSE  RMSE   R2  MAPE (%)
# 0       Lasso(alpha=1.0)  standard 3.27 20.08  4.48 0.98      3.53
# 1       Lasso(alpha=0.1)  standard 3.32 19.34  4.40 0.98      3.74
# 2      Lasso(alpha=10.0)  no_scale 3.32 19.31  4.39 0.98      3.74
# 3  SGD(squared_loss, l1)  standard 3.33 19.38  4.40 0.98      3.74
# 4      Lasso(alpha=0.01)    minmax 3.33 19.41  4.41 0.98      3.76
#
# Базовый MAE = 28.6300
# Моделей лучше базовой: 44
#
# Лучшая модель: Lasso(alpha=1.0) на датасете standard
# MAE = 3.2700, R2 = 0.9800

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Обучены все требуемые архитектуры: LinearRegression, Lasso, Ridge, SGDRegressor. Перебраны разные значения alpha, типы регуляризации и функции потерь. Зафиксирован random_state=42. Итоговая таблица отсортирована по MAE и содержит колонку с типом масштабирования - все верно.
# </div>

# %% [markdown]
# ### 6.7 Промежуточный итог

# %% [markdown]
# В ходе эксперимента было обучено и протестировано различных конфигураций моделей (включая вариации масштабирования, типов регуляризации, гиперпараметров). Все модели, за исключением базовой Dummy, показали результаты, значительно превосходящие наивное предсказание средним значением (`MAE` = 28.63 кг).
#
# **Ключевые наблюдения:**
# 1. <u>Эффективность линейных моделей:</u>
#
# Линейная регрессия без регуляризации (`LinearRegression`) показала результаты, сопоставимые с регуляризованными моделями (`MAE` ~ 3.35 кг, `R2` = 0.98). Это важный индикатор того, что зависимость между биометрическими признаками и массой черепахи действительно близка к линейной, а количество признаков (14) значительно меньше числа наблюдений (1434 в обучающей выборке), что исключает риск переобучения.
#
# 2. <u>Влияние масштабирования:</u>
# - Стандартизация (`StandardScaler`) оказалась наиболее эффективным методом предобработки, особенно для моделей, c `L1`-регуляризацией (`Lasso`).
# - `MinMaxScaler` показал сопоставимые, но в среднем чуть более низкие результаты.
# - Интересно, что `Lasso` без масштабирования с высоким значением `alpha`=10.0 вошла в топ-5 лучших моделей. Это объясняется тем, что `L1`-регуляризация сама по себе может отбирать признаки, частично компенсируя разницу в их масштабах.
#
# 3. <u>Сравнение типов регуляризации:</u>
# - `Lasso` (L1-регуляризация): Показала наилучший результат среди всех моделей. Конфигурация `Lasso(alpha=1.0)` на стандартизированных данных заняла 1-е место с `MAE = 3.27` кг.
# - `Ridge` (L2-регуляризация): Показала стабильно высокие результаты, близкие к `LinearRegression`, но не смогла превзойти лучшую модель `Lasso`.
# - `SGDRegressor`: Конфигурации с функцией потерь `squared_loss` и различными типами регуляризации показали очень хорошие результаты, войдя в топ-5 (`MAE = 3.33` кг).
#
# 4. <u>Анализ лучших моделей:</u>
# - Топ-1: `Lasso(alpha=1.0)` на датасете standard (MAE = 3.27 кг, R2 = 0.98).
# - Топ-2: `Lasso(alpha=0.1)` на датасете standard (MAE = 3.32 кг, R2 = 0.98).
# - Топ-3: `Lasso(alpha=10.0)` на датасете no_scale (MAE = 3.32 кг, R2 = 0.98).
# - Топ-4: `SGD(squared_loss, l1)` на датасете standard (MAE = 3.33 кг, R2 = 0.98).
# - Топ-5: `Lasso(alpha=0.01)` на датасете minmax (MAE = 3.33 кг, R2 = 0.98).
#
# Все топ-5 моделей имеют `MAE` менее 3.4 кг, что более чем в 8 раз лучше базового уровня (28.63 кг).
#
# 5. <u>Соответствие требованиям заказчика:</u>
#
# Все модели из топ-5 удовлетворяют жёстким критериям, определённым в техническом задании:
# - `MAE ≤ 5` кг — выполняется с большим запасом (фактическое значение ~3.3 кг).
# - `R² ≥ 0.97` — фактическое значение (0.98) превышает порог, что означает, что модель объясняет 98% дисперсии целевой переменной.
# - Линейность модели — все обученные модели являются линейными, что позволяет легко интерпретировать коэффициенты и реализовать в виде простой формулы.
#
# 6. <u>Вывод:</u>
#
# На валидационной выборке наилучшие результаты показала модель `Lasso` с параметром `alpha=1.0` в сочетании со стандартизацией признаков (`StandardScaler`). Данная конфигурация обеспечивает `MAE = 3.27` кг и `R2 = 0.98`, что полностью соответствует и даже превосходит требования заказчика. Модель демонстрирует высокую стабильность, и её качество будет дополнительно подтверждено на тестовой выборке в следующем разделе.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# В выводе ты пишешь: "Топ-1: MAE = 3.72 кг, R2 ≈ 1.00", но в таблице результатов выше MAE = 3.84 и R2 = 0.98. Числа в тексте должны точно совпадать с тем, что напечатано в принтах. Это очень важно - всегда сверять цифры в выводах с реальными результатами.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Так как таинственные для меня вещи продолжаются (модели выдали в тренажере другие значения, нежели у меня локально), то выводы были сформированны не по корректным данным.
#
# Скорректировал вывод на основе актуальных данных
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# ## 7. Проверка лучшей модели на тестовой выборке <a id=7></a>

# %%
# Создадим модель на основе параметров лучшей модели
lasso_pipe = make_pipeline(StandardScaler(), Lasso(alpha=1.0, random_state=42))
lasso_pipe.fit(X_train, y_train)
y_pred =lasso_pipe.predict(X_test)
get_metrics(y_test, y_pred, f'Lasso(alpha=1.0)', 'X_test')
# Out:
#               Model Dataset  MAE   MSE  RMSE   R2  MAPE (%)
# 0  Lasso(alpha=1.0)  X_test 3.58 22.33  4.73 0.98      3.87

# %% [markdown]
# **Вывод по тестированию:**
# - Лучшая модель `Lasso(alpha=1.0)` на датасете `standard`  показала на тестовой выборке:
#   - *MAE = 3.58 кг* (≤ 5 кг — требование выполнено)
#   - *R2 = 0.98* (≥ 0.97 — требование выполнено)
#   - *MAPE = 3.87%* (относительная ошибка менее 4%, что отлично для разных возрастных групп)
# - Сравнение с валидацией (MAE = 3.27 кг, R2 = 0.98):
#   - Метрики на тесте незначительно отличаются, что свидетельствует об отсутствии переобучения.
# - *Рекомендация:* Модель полностью соответствует требованиям заказчика и может быть рекомендована к внедрению в систему `TurtleCV` для оценки массы зелёных морских черепах.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Метрики на тестовой выборке посчитаны корректно. MAE = 3.54 < 5, R² = 0.98 > 0.97 - оба требования заказчика выполнены. Есть сравнение с валидационной выборкой и вывод об отсутствии переобучения.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# И снова в выводе: "MAE = 3.53 кг", но в таблице выше 3.54. Приведи, пожалуйста, цифры в соответствие.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Переписал модель с `SGDRegresso` на `Lasso `, так как у меня изменилась лучшая модель на валидационной выборке. На основе новых данных скорректировал вывод.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# ## 8. Оценка важности признаков <a id=8></a>

# %%
# Определим расчитанные коэффициенты модели
lasso_model = lasso_pipe.named_steps['lasso']
feat_names = X_test.columns

print("Коэффициенты:\n", pd.DataFrame({
    'Признаки': feat_names,
    'Коэффициенты': lasso_model.coef_
}))
print("\nСмещение:", round(lasso_model.intercept_, 2))
# Out:
# Коэффициенты:
#              Признаки  Коэффициенты
# 0       shell_length         15.66
# 1        shell_width          6.25
# 2        head_length          1.12
# 3         head_width          0.72
# 4   flipper_length_1          2.14
# 5    flipper_width_1          1.08
# 6   flipper_length_2          1.45
# 7    flipper_width_2          1.22
# 8   flipper_length_3          1.73
# 9    flipper_width_3          1.04
# 10  flipper_length_4          1.35
# 11   flipper_width_4          1.13
# 12      circle_count          0.00
# 13       shell_crack          0.00
#
# Смещение: 97.15

# %% [markdown]
# **Вывод о важности признаков:**
#
# На основе анализа полученных коэффициентов линейной регрессии с L1-регуляризацией (Lasso) можно сделать следующие выводы:
#
# Наиболее важные признаки для предсказания массы черепахи:
# `shell_length`, `shell_width`.
#
# Признаки `circle_count` и `shell_crack` получили нулевые коэффициенты, что при `Lasso` означает их исключение из модели как незначимых для предсказания на масштабированных данных.
#
# *Результаты хорошо согласуются с логикой:*
# - Основной вклад вносит размер панциря (`shell_length`, `shell_width`) — это ожидаемо, так как они напрямую связаны с объемом и массой тела.
# - Размеры ласт и головы также важны, но в меньшей степени.
# - Возраст (`circle_count`) и наличие трещины на панцире (`shell_crack`) в данной модели оказались неинформативными.
#
# *Практическая ценность:*
#
# Модель `Lasso` автоматически выполнила отбор признаков, обнулив `circle_count` и `shell_crack`. Это позволяет упростить сбор данных для системы `TurtleCV` — указанные признаки можно не использовать без потери качества предсказания. Наиболее критичны для измерения: длина и ширина панциря, размеры ласт и головы.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Ты пишешь: "Наиболее важные признаки: shell_crack, shell_length, shell_width, circle_count". Но если посмотреть на таблицу коэффициентов выше, то shell_length = 14.85 - это явно самый большой коэффициент, а shell_crack = 0.04 - один из наименьших. Важность признака определяется по абсолютному значению коэффициента при масштабированных данных, поэтому shell_crack никак не является наиболее важным. Интерпретация в выводе прямо противоречит выведенным числам. Поправь, пожалуйста.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Исправил вывод по важности признаков. Так же переписал код в ячейке, так как ранее коэфициенты расчитывались для модели `SGDRegresso`, а нужно для `Lasso`
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 👍
#
# </div>

# %% [markdown]
# ## 9. Функция для прогнозирования веса черепахи <a id=9></a>

# %%
# Создадим функцию предскозания веса
def predict_weight(features):
    coef_array = np.array(lasso_model.coef_)
    intercept = lasso_model.intercept_
    
    scal = lasso_pipe.named_steps['standardscaler']

    features_array = np.array(features[:-1]).reshape(1, -1)
    feature_scaled = scal.transform(features_array)

    prediction = np.dot(feature_scaled, coef_array) + intercept
    
    return prediction

# %%
# Проводим тестирование функции предскозания
num_obj = 256
test_features = c_mydas_df.iloc[num_obj]
my_pred = predict_weight(test_features)
pipe_pred = lasso_pipe.predict(np.array(test_features[:-1]).reshape(1, -1))

print(f'Данные для предскозания:\n{c_mydas_df.iloc[num_obj]}')
print(f"\nПредсказание через функцию: {my_pred}")
print(f'Предсказание через pipeline: {pipe_pred}')
print(f'Разница: {abs(my_pred[0] - pipe_pred[0])}')
# Out:
# Данные для предскозания:
# shell_length       1195.00
# shell_width        1105.00
# head_length         211.00
# head_width          234.00
# flipper_length_1    698.00
# flipper_width_1     663.00
# flipper_length_2    684.00
# flipper_width_2     548.00
# flipper_length_3    598.00
# flipper_width_3     453.00
# flipper_length_4    527.00
# flipper_width_4     497.00
# circle_count         84.00
# shell_crack           0.00
# weight              121.13
# Name: 772, dtype: float64
#
# Предсказание через функцию: [122.10896236]
# Предсказание через pipeline: [122.10896236]
# Разница: 0.0

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Функция predict_weight создаёт новый StandardScaler() внутри себя и заново обучает его на X_train при каждом вызове. Правильнее использовать уже обученный скейлер из пайплайна: sgd_pipe.named_steps['standardscaler']. Так параметры масштабирования гарантированно совпадут с теми, на которых обучалась модель. Также внутри функции есть отладочный print(scal.mean_, scal.scale_) - его нужно убрать из финальной версии. И самое главное - функция не протестирована: нет вызова с примером входных данных и сравнения результата с предсказанием sgd_pipe.predict().
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Воспользовался в функции обученным скейлером, убрал отладочные команды. Так же переписал функциию на модель `Lasso`
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.2</b><br><br>
# 📝
# Уже лучше, но функция всё ещё не протестирована должным образом: нет сравнения результата с lasso_pipe.predict(). Есть вызов с примером и вывод предсказания (70.47), но нет проверки что это совпадает с результатом пайплайна.
#
# Можно добавить:
#
# ```pythonpipe_pred = lasso_pipe.predict(np.array(test_features[:-1]).reshape(1, -1))
# print(f'Предсказание через pipeline: {pipe_pred}')
# print(f'Разница: {abs(my_pred[0] - pipe_pred[0])}')```
# </div>

# %% [markdown]
# ## 10. Общие выводы и рекомендации по дальнейшей работе <a id=10></a>

# %% [markdown]
# **Какие модели изучены?**
# В ходе проекта были обучены и сравнены следующие модели регрессии:
# - `DummyRegressor` (базовый уровень)
# - `LinearRegression` (без регуляризации)
# - `Lasso` (L1-регуляризация)
# - `Ridge` (L2-регуляризация)
# - `SGDRegressor` (стохастический градиентный спуск с различными функциями потерь и типами регуляризации)
#
# **Какие результаты получены?**
# - Базовая модель показала `MAE` = 28.63 кг.
# - Лучшая модель (`Lasso(alpha=1.0)` на датасете `standard`) достигла на тестовой выборке:
#   - *MAE = 3.58 кг
#   - *R2 = 0.98
#   - *MAPE = 3.87%
# - Все ключевые требования заказчика (`MAE` ≤ 5 кг, `R²` ≥ 0.97) выполнены.
#
# **Рекомендуется ли итоговая модель к внедрению?**
# *Да, рекомендуется.* Модель показывает стабильно высокое качество на тестовой выборке, отсутствие переобучения и удовлетворяет всем критериям. Она может быть интегрирована в систему `TurtleCV` для бесконтактного определения массы зелёных морских черепах.
#
# **Какая архитектура и способ обработки признаков показали себя лучше всего? Какие у них показатели метрик?**
# - *Лучшая архитектура:* `Lasso(alpha=1.0)`.
# - *Способ обработки признаков:* стандартизация (`StandardScaler`).
# - *Показатели на тесте:* `MAE` = 3.58 кг, `R2` = 0.98, `MAPE` = 3.87%.
#
# **Какие признаки наиболее важны для модели?**
#
# Наиболее важными признакими являются `shell_length`, `shell_width`. Оставшиеся биометрические паказатели имеют важность не не сильно.
#
# **Есть ли перспективы у обучения этой или других моделей для предсказания массы других видов черепах?**
# - *Да, перспективы высоки.* Данный подход (линейная регрессия на биометрических признаках) может быть распространён на другие виды (`Caretta caretta`, `Lepidochelys olivacea` и др.) при наличии достаточного количества размеченных данных.
# - Для каждого вида, вероятно, потребуется своя модель, так как соотношения размеров и массы могут различаться.
#
# **Предложения по дальнейшему развитию проекта:**
# 1. *Борьба с мультиколлинеарностью:* оставить только наиболее информативные признаки (например, только `shell_length`, `shell_width`).
# 2. *Добавление новых признаков:* вычислить производные (площадь панциря, объём по формуле эллипсоида) — они могут иметь более прямую физическую связь с массой.
# 3. *Проверка на других видах:* собрать аналогичные датасеты для других видов черепах и обучить отдельные модели.
# 4. *Сравнение с нелинейными моделями:* хотя по ТЗ требуется линейная модель, для научных целей можно сравнить с `Random Forest` или `Gradient Boosting`.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Выводы написаны структурировано и отвечают на все вопросы задания. Хорошо, что есть конкретные предложения по дальнейшему развитию проекта, в том числе про создание производных признаков (площадь панциря) и обучение отдельных моделей для других видов.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# В выводе ты снова пишешь: "Базовая модель показала MAE = 34.69 кг", но в таблице результатов dummy MAE = 29.39. Это ещё одно расхождение чисел в тексте с реальными принтами - нужно исправить.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v.1</b>
#
# Скорректировал финальный вывод основываясь на новых данных.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.1</b><br><br>
# Михаил, проект написан структурировано. Хорошо описана постановка задачи, подробные выводы по каждому разделу, грамотное использование пайплайнов и широкий перебор конфигураций моделей. Видно, что к работе ты подошёл очень серьёзно.
#
# **Что нужно доработать:**
#
# * Дубликаты удаляются только по registration number - нужно удалять полные дубликаты, совпадающие по всем признакам.
#
# * Выбросы исправлены только в shell_length, но не в shell_width - нужно применить то же исправление к shell_width.
#
# * Пропуски в признаках удалены до разбивки на выборки - в следующих проектах обрабатывай пропуски после train_test_split.
#
# * Интерпретация корреляционной матрицы выглядит неверной - проверь значения на графике.
#
# * В нескольких местах числа в текстовых выводах не совпадают с реальными принтами - приведи их в соответствие.
#
# * Интерпретация важности признаков противоречит коэффициентам модели - shell_crack с коэффициентом 0.04 не является важным признаком.
#
# * Функцию predict_weight нужно исправить и протестировать.
#
# Жду исправленную версию проекта. Удачи в доработках!

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.2</b><br><br>
# Михаил, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
